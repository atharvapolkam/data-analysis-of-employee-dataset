# %% [raw]
# You are provided with a dataset containing information about a company's employees.
# Your task is to analyze the data and provide insights on the following questions:
#
# What is the average salary of employees by department?
# Which department has the highest number of employees?
# What is the distribution of gender in the company?
# Is there a correlation between years of experience and salary?
# Which department has the highest average salary?
#
# Data:
#
# The dataset contains the following columns:
#
# Employee ID: unique identifier for each employee
# Department: the department the employee belongs to
# Gender: the gender of the employee (M for male, F for female)
# Years of Experience: the number of years the employee has worked at the company
# Salary: the salary of the employee
# Instructions:
#
# Load the dataset into your preferred data analysis tool (e.g. Excel, Python, R).
# Clean and prepare the data as necessary.
# Answer each of the questions above, providing relevant statistics, visualizations,
# or any other analysis you deem necessary.
# Present your findings in a clear and concise report or presentation format,
# along with any relevant code or scripts used to perform the analysis.
# Evaluation criteria:

# %%
#Importing important libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings


warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# # Reading the data

# %%
data = pd.read_csv('D:\data science\employee dataset eda\employees Datset.csv')

# %%
data
# Out:
#      Employee ID First Name  Gender  Salary            Department  \
# 0              1    Douglas    Male   97308             Marketing
# 1              2     Thomas    Male   61933               Finance
# 2              3      Maria  Female  130590               Finance
# 3              4      Jerry    Male  138705       Client Services
# 4              5      Larry    Male  101004                 Legal
# ..           ...        ...     ...     ...                   ...
# 850          851       Lois    Male  148291               Finance
# 851          852        Ann    Male  147842                 Sales
# 852          853       Todd    Male  105066  Business Development
# 853          854    Marilyn    Male  139284             Marketing
# 854          855      Shawn    Male   63046  Business Development
#
#      Years of experience
# 0                     29
# 1                     27
# 2                     30
# 3                     18
# 4                     25
# ...

# %%
#displaying first 5 rows of dataset
data.head()
# Out:
#    Employee ID First Name  Gender  Salary       Department  \
# 0            1    Douglas    Male   97308        Marketing
# 1            2     Thomas    Male   61933          Finance
# 2            3      Maria  Female  130590          Finance
# 3            4      Jerry    Male  138705  Client Services
# 4            5      Larry    Male  101004            Legal
#
#    Years of experience
# 0                   29
# 1                   27
# 2                   30
# 3                   18
# 4                   25

# %%
#displaying last 5 rows of dataset
data.tail()
# Out:
#      Employee ID First Name Gender  Salary            Department  \
# 850          851       Lois   Male  148291               Finance
# 851          852        Ann   Male  147842                 Sales
# 852          853       Todd   Male  105066  Business Development
# 853          854    Marilyn   Male  139284             Marketing
# 854          855      Shawn   Male   63046  Business Development
#
#      Years of experience
# 850                   25
# 851                   26
# 852                   18
# 853                   16
# 854                   38

# %%
#know the datatypes
data.dtypes
# Out:
# Employee ID             int64
# First Name             object
# Gender                 object
# Salary                  int64
# Department             object
# Years of experience     int64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 855 entries, 0 to 854
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Employee ID          855 non-null    int64
#  1   First Name           855 non-null    object
#  2   Gender               855 non-null    object
#  3   Salary               855 non-null    int64
#  4   Department           855 non-null    object
#  5   Years of experience  855 non-null    int64
# dtypes: int64(3), object(3)
# memory usage: 40.2+ KB

# %%
#displaying the shape of dataset : No. of rows and No. of columns
data.shape
# Out:
# (855, 6)

# %%
#getting overall statistics about the dataframe
data.describe(include='all')
# Out:
#         Employee ID First Name  Gender         Salary Department  \
# count    855.000000        855     855     855.000000        855
# unique          NaN        200       2            NaN         10
# top             NaN    Marilyn  Female            NaN    Finance
# freq            NaN         11     431            NaN         95
# mean     428.000000        NaN     NaN   90555.422222        NaN
# std      246.961535        NaN     NaN   32807.339017        NaN
# min        1.000000        NaN     NaN   35013.000000        NaN
# 25%      214.500000        NaN     NaN   62816.000000        NaN
# 50%      428.000000        NaN     NaN   89786.000000        NaN
# 75%      641.500000        NaN     NaN  118582.000000        NaN
# max      855.000000        NaN     NaN  149908.000000        NaN
#
#         Years of experience
# count            855.000000
# unique                  NaN
# top                     NaN
# freq                    NaN
# mean              24.170760
# ...

# %%
#getting overall statistics about the dataframe
data.columns
# Out:
# Index(['Employee ID', 'First Name', 'Gender', 'Salary', 'Department',
#        'Years of experience'],
#       dtype='object')

# %%
data.nunique()
# Out:
# Employee ID            855
# First Name             200
# Gender                   2
# Salary                 850
# Department              10
# Years of experience     38
# dtype: int64

# %%
#checking for null values.
data.isnull().sum()
# Out:
# Employee ID            0
# First Name             0
# Gender                 0
# Salary                 0
# Department             0
# Years of experience    0
# dtype: int64

# %% [markdown]
# # Relationship Analysis

# %%
#HISTOGRAM

#A histogram is basically used to represent data provided in a form of some groups.It is accurate method for the graphical 
#representation of numerical data distribution.It is a type of bar plot where X-axis represents the bin ranges while Y-axis 
#gives information about frequency.

data.hist(figsize=(20,14),color='b')
# Out:
# array([[<AxesSubplot:title={'center':'Employee ID'}>,
#         <AxesSubplot:title={'center':'Salary'}>],
#        [<AxesSubplot:title={'center':'Years of experience'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
#LINEPLOT
#A Line plot can be defined as a graph that displays data as points or check marks above a number line, showing the frequency
#of each value.

sns.lineplot(x='Years of experience',y='Salary',data=data,color='g')
# Out:
# <AxesSubplot:xlabel='Years of experience', ylabel='Salary'>

# %%
#PAIRPLOT

#A pairplot plot a pairwise relationships in a dataset. The pairplot function creates a grid of Axes such that each variable in
#data will by shared in the y-axis across a single row and in the x-axis across a single column.
sns.pairplot(data)

# %%
#JOINTPLOT

#Seaborn's jointplot displays a relationship between 2 variables (bivariate) as well as 1D profiles (univariate) in the margins.
#This plot is a convenience class that wraps JointGrid.

sns.jointplot(x='Years of experience',y='Salary',data=data,color='r')

# %%
sns.scatterplot(data['Years of experience'],data['Salary'])
# Out:
# <AxesSubplot:xlabel='Years of experience', ylabel='Salary'>

# %% [markdown]
# # Questions

# %%
1)What is the average salary of employees by department?
2)Which department has highest average salary?

# %%
data.groupby(by="Department")["Salary"].mean(())
# Out:
# Department
# Business Development    90609.235294
# Client Services         93965.157895
# Distribution            95798.884615
# Engineering             88713.730769
# Finance                 89784.294737
# Human Resources         86973.168675
# Legal                   87437.175000
# Marketing               93883.411111
# Product                 89868.977011
# Sales                   88012.666667
# Name: Salary, dtype: float64

# %% [markdown]
# As per data The Average salary of employees are given above
# from the data we can say that highest average salary is
# from DISTRIBUTION DEPARTMENT lowest average salary is getting
# from HUMAN RESOURCES DEPARTMENT

# %%
3)Which department has the highest number of employees

# %%
data.groupby(by="Department").count()
# Out:
#                       Employee ID  First Name  Gender  Salary  \
# Department
# Business Development           85          85      85      85
# Client Services                95          95      95      95
# Distribution                   78          78      78      78
# Engineering                    78          78      78      78
# Finance                        95          95      95      95
# Human Resources                83          83      83      83
# Legal                          80          80      80      80
# Marketing                      90          90      90      90
# Product                        87          87      87      87
# Sales                          84          84      84      84
#
#                       Years of experience
# Department
# Business Development                   85
# Client Services                        95
# Distribution                           78
# Engineering                            78
# Finance                                95
# ...

# %% [markdown]
# Highest number of employees is from both  client services and finance department with 95 employees

# %%
4)Is there a correlation between years of experience and salary

# %%
#HEATMAP

#A heatmap is a graphical representation of data that uses a system of color-coding to represent different values. 
#using a correlation heatmap to view rlationship between variables
sns.heatmap(data.corr(),annot=True,cmap='viridis',linewidths=.5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Value of correlation between years of experience and salary is -0.04 so we can conclude that there is no
# significance relation between both column(according to data)

# %%
5)What is the distribution of gender in the company

# %%
k=data.Gender

# %%
k.describe()
# Out:
# count        855
# unique         2
# top       Female
# freq         431
# Name: Gender, dtype: object

# %%
data['Gender'].value_counts().plot(kind="pie", autopct="%.2f")
plt.show()

# %% [markdown]
# female count: 431 , male count : 424
